# %%
import torch
import torch.nn as nn
import numpy as np
from math import sqrt
from matplotlib import pyplot as plt
from tqdm import tqdm
import quantecon as qe

# Set device - use GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %% [markdown]
# ## Model Parameters

# %%
# Preferences
beta = 0.9      # Discount factor
gamma = 2.0     # Risk aversion (CRRA)
r = (1/beta-1) * 0.9

# Income process (log-AR(1))
rho_Z = 0.9       # Persistence
sigma_Z = 0.2     # Shock standard deviation
mu_Z = np.exp(1/2 * sigma_Z**2 / (1 - rho_Z**2))

nA = 1000
Amin = 0.0
Amax = 5.0
A_grid = np.linspace(Amin, Amax, nA)

# %%
def coh_fun(Z, A):
    return A * (1+r) + Z

def c_fun(savings_rate, Z, A):
    """Consumption function given savings rate, TFP Z and assets A"""
    coh = coh_fun(Z, A)
    return (1 - savings_rate) * coh

# %%
class DecisionNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(2, 32), # two inputs 
            nn.ReLU(),
            nn.Linear(32, 32),
            nn.ReLU(),
            nn.Linear(32, 32),
            nn.ReLU(),
            nn.Linear(32, 2) # two outputs
        )
        
    def forward(self, x):
        return self.net(x)


network = DecisionNetwork().to(device)

# %%
def policy_function(Z, A):
    """Decision rule: maps states to savings rate"""
    
    # Normalize inputs to roughly [-1, 1] range
    Z_normalized = (Z-mu_Z) / sigma_Z / 2
    A_normalized = 2.0 * (A - Amin) / (Amax - Amin) - 1.0
    
    # Stack inputs: shape (n, 2)
    s = torch.stack([Z_normalized, A_normalized], dim=1)
    
    # Forward pass through network
    x = network(s)  # (n, 2)
    
    # Savings rate in [0,1]
    savings_rate = torch.sigmoid(x[:, 0])
    #lagrange = torch.nn.functional.softplus(x[:, 1])
    lagrange = torch.exp(x[:, 1])
    #lagrange = torch.sigmoid(x[:, 1])
    
    return torch.clamp(savings_rate, max=0.999), lagrange

# %%
# Here is the Fischer-Burmeister (FB) in PyTorch:
min_FB = lambda a,b: a+b-torch.sqrt(a**2+b**2)

def euler_residuals(Z, A, eps):
    # Current decisions
    savings_rate, lagrange = policy_function(Z, A)
    coh = coh_fun(Z, A)
    A_next = savings_rate * coh

    # Clamp A_next to valid asset range
    A_next = torch.clamp(A_next, min=Amin, max=Amax)

    C = coh - A_next

    Z_next = torch.exp(rho_Z * torch.log(Z) + eps)

    # Next-period policy and consumption (vectorized over shocks)
    savings_rate_next, _ = policy_function(Z_next, A_next)
    C_next = c_fun(savings_rate_next, Z_next, A_next)

    # Future returns and marginal utility (Monte Carlo expectation)
    MU_next = C_next**(-gamma)
    RHS = beta * MU_next * (1.0 + r) 
    
    # Residual
    FOC = RHS / C**(-gamma) - lagrange
    slackness = min_FB(1-lagrange, savings_rate)
    return FOC, slackness

# %% [markdown]
# ## Objective Function

# %%
def sample_Z_ergodic(n, rho, sigma_eps, *, device=None, dtype=torch.float32):
    if not (-1.0 < rho < 1.0):
        raise ValueError("Need |rho| < 1 for a stationary (ergodic) distribution.")
    device = device or torch.device("cpu")
    rho = torch.as_tensor(rho, device=device, dtype=dtype)
    sigma_eps = torch.as_tensor(sigma_eps, device=device, dtype=dtype)

    sigma_x = sigma_eps / torch.sqrt(1.0 - rho**2)          # std of log Z in stationarity
    x = sigma_x * torch.randn(n, device=device, dtype=dtype) # mean 0
    Z = torch.exp(x)
    return Z

def objective_function(n):

    # Sample current states from ergodic distribution
    Z = sample_Z_ergodic(n, rho_Z, sigma_Z, device=device)
    A = torch.rand(n, device=device) * (Amax - Amin) + Amin

    # Monte Carlo expectation with n_shocks draws per state
    eps1 = sigma_Z * torch.randn(n, device=device)
    FOC1, slackness1 = euler_residuals(Z, A, eps1)

    eps2 = sigma_Z * torch.randn(n, device=device)
    FOC2, slackness2 = euler_residuals(Z, A, eps2)

    FOC = FOC1*FOC2
    slackness = slackness1*slackness2
    return torch.mean(FOC + slackness)

# %%
base_lr = 1e-3

optimizer = torch.optim.Adam(network.parameters(), lr=base_lr)

n = 128

def training_step():
    optimizer.zero_grad()
    loss = objective_function(n)  
    loss.backward()
    optimizer.step()
    return loss.item()

def train(K):
    vals = []
    for k in tqdm(range(K)):
        val = training_step()
        vals.append(val)
    return vals

# %%
results = train(100_000)
# Out:
# 100%|██████████| 100000/100000 [01:28<00:00, 1123.63it/s]

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.sqrt(np.abs(results)))  # abs() for numerical safety
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('RMSE of Residuals')
plt.title('Training Convergence')
plt.grid(True, which="both", ls="-", alpha=0.5)
plt.show()

# %% [markdown]
# ## Learned Decision Rule

# %%
from consav_vfi import vfi, A_grid as A_grid_vfi

_, policy_A = vfi(tol = 1e-6, max_iter = 1000, verbose = True)
# Out:
# Iteration 1: max value function diff = 4.70548513
# Iteration 2: max value function diff = 3.12288521
# Iteration 3: max value function diff = 2.17572446
# Iteration 4: max value function diff = 1.56294072
# Iteration 5: max value function diff = 1.14628756
# Iteration 6: max value function diff = 0.85368516
# Iteration 7: max value function diff = 0.64359856
# Iteration 8: max value function diff = 0.49000573
# Iteration 9: max value function diff = 0.37624950
# Iteration 10: max value function diff = 0.29106889
# Iteration 11: max value function diff = 0.22670018
# Iteration 12: max value function diff = 0.17767238
# Iteration 13: max value function diff = 0.14007179
# Iteration 14: max value function diff = 0.11105197
# Iteration 15: max value function diff = 0.08852314
# Iteration 16: max value function diff = 0.07093717
# Iteration 17: max value function diff = 0.05713566
# Iteration 18: max value function diff = 0.04624821
# Iteration 19: max value function diff = 0.03761621
# Iteration 20: max value function diff = 0.03073875
# Iteration 21: max value function diff = 0.02523301
# Iteration 22: max value function diff = 0.02080499
# Iteration 23: max value function diff = 0.01722769
# Iteration 24: max value function diff = 0.01432522
# Iteration 25: max value function diff = 0.01196062
# Iteration 26: max value function diff = 0.01002664
# Iteration 27: max value function diff = 0.00843913
# Iteration 28: max value function diff = 0.00713284
# Iteration 29: max value function diff = 0.00605879
# Iteration 30: max value function diff = 0.00516305
# Iteration 31: max value function diff = 0.00441336
# Iteration 32: max value function diff = 0.00378363
# Iteration 33: max value function diff = 0.00325295
# Iteration 34: max value function diff = 0.00280347
# Iteration 35: max value function diff = 0.00242191
# Iteration 36: max value function diff = 0.00209709
# Iteration 37: max value function diff = 0.00181968
# Iteration 38: max value function diff = 0.00158243
# Iteration 39: max value function diff = 0.00137829
# Iteration 40: max value function diff = 0.00120287
# Iteration 41: max value function diff = 0.00105124
# Iteration 42: max value function diff = 0.00092017
# Iteration 43: max value function diff = 0.00080666
# Iteration 44: max value function diff = 0.00070817
# Iteration 45: max value function diff = 0.00062252
# Iteration 46: max value function diff = 0.00054792
# Iteration 47: max value function diff = 0.00048280
# Iteration 48: max value function diff = 0.00042623
# Iteration 49: max value function diff = 0.00037628
# Iteration 50: max value function diff = 0.00033256
# Iteration 51: max value function diff = 0.00029420
# Iteration 52: max value function diff = 0.00026054
# Iteration 53: max value function diff = 0.00023094
# Iteration 54: max value function diff = 0.00020520
# Iteration 55: max value function diff = 0.00018205
# Iteration 56: max value function diff = 0.00016193
# Iteration 57: max value function diff = 0.00014385
# Iteration 58: max value function diff = 0.00012792
# Iteration 59: max value function diff = 0.00011413
# Iteration 60: max value function diff = 0.00010154
# Iteration 61: max value function diff = 0.00009045
# Iteration 62: max value function diff = 0.00008063
# Iteration 63: max value function diff = 0.00007192
# Iteration 64: max value function diff = 0.00006421
# Iteration 65: max value function diff = 0.00005766
# Iteration 66: max value function diff = 0.00005139
# Iteration 67: max value function diff = 0.00004588
# Iteration 68: max value function diff = 0.00004100
# Iteration 69: max value function diff = 0.00003666
# Iteration 70: max value function diff = 0.00003279
# Iteration 71: max value function diff = 0.00002967
# Iteration 72: max value function diff = 0.00002645
# Iteration 73: max value function diff = 0.00002363
# Iteration 74: max value function diff = 0.00002114
# Iteration 75: max value function diff = 0.00001923
# Iteration 76: max value function diff = 0.00001711
# Iteration 77: max value function diff = 0.00001528
# Iteration 78: max value function diff = 0.00001368
# Iteration 79: max value function diff = 0.00001225
# Iteration 80: max value function diff = 0.00001129
# Iteration 81: max value function diff = 0.00001001
# Iteration 82: max value function diff = 0.00000916
# Iteration 83: max value function diff = 0.00000810
# Iteration 84: max value function diff = 0.00000721
# Iteration 85: max value function diff = 0.00000672
# Iteration 86: max value function diff = 0.00000591
# Iteration 87: max value function diff = 0.00000524
# Iteration 88: max value function diff = 0.00000468
# Iteration 89: max value function diff = 0.00000449
# Iteration 90: max value function diff = 0.00000390
# Iteration 91: max value function diff = 0.00000345
# Iteration 92: max value function diff = 0.00000307
# Iteration 93: max value function diff = 0.00000304
# Iteration 94: max value function diff = 0.00000260
# Iteration 95: max value function diff = 0.00000228
# Iteration 96: max value function diff = 0.00000229
# Iteration 97: max value function diff = 0.00000193
# Iteration 98: max value function diff = 0.00000168
# Iteration 99: max value function diff = 0.00000148
# Iteration 100: max value function diff = 0.00000161
# Iteration 101: max value function diff = 0.00000132
# Iteration 102: max value function diff = 0.00000113
# Iteration 103: max value function diff = 0.00000126
# Iteration 104: max value function diff = 0.00000100
# Iteration 105: max value function diff = 0.00000084
#
# Converged after 105 iterations!

# %%
with torch.no_grad():
    A_grid = torch.tensor(A_grid, dtype=torch.float32, device=device)
    ones = torch.ones_like(A_grid)  # Z = 1 (level value at steady state)
    savings_rate_vec, _ = policy_function(ones, A_grid)

# VFI savings rate for a representative Z index
coh_vfi = A_grid * (1 + r) + 1.0 
savings_rate_vfi = policy_A[4, :] / coh_vfi

plt.plot(A_grid.cpu(), savings_rate_vec.cpu(), label='DL')
plt.plot(A_grid, savings_rate_vfi, linestyle='--', label='VFI')
plt.xlabel("Assets A")
plt.ylabel("Savings rate")
plt.title("Savings Rate")
plt.xlim(-0.1, Amax)
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

coh = coh_fun(ones, A_grid)
A_next_dl = savings_rate_vec * coh
A_next_vfi = policy_A[4, :]

plt.plot(A_grid.cpu(), np.zeros_like(A_grid.cpu()), 'k--', alpha=0.5, label='45° line')
plt.plot(A_grid_vfi, A_next_vfi - A_grid_vfi, label='VFI')
plt.plot(A_grid.cpu(), A_next_dl.cpu() - A_grid.cpu(), label='DL', linestyle=':')
plt.xlabel('Assets A')
plt.ylabel("A'(Z, A)")
plt.title('Asset Policy')
plt.xlim(-0.1, Amax)
plt.ylim(-0.25, 0.25)
plt.legend()
plt.grid()
plt.show()
