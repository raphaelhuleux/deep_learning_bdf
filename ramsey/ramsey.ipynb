# %%
import torch
import torch.nn as nn
import numpy as np
from math import sqrt
from matplotlib import pyplot as plt
from tqdm import tqdm

# Set device - use GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %% [markdown]
# ## Model Parameters

# %%
## Preferences
beta = 0.9 
gamma = 2.0 

## Firms
alpha = 1/3 
delta = 0.05

# %%
def production_function(K):
    """Cobb-Douglas production function"""
    return K**alpha 

def coh_fun(K):
    return production_function(K) + (1 - delta) * K

def r_fun(K):
    """Return the interest rate given Z and K"""
    return alpha * production_function(K) / K - delta 

def c_fun(savings_rate, K):
    """Consumption function given savings rate, TFP Z and capital K"""
    coh = coh_fun(K)
    return (1 - savings_rate) * coh

# %%
# Steady-state 
r = 1/beta - 1 
K_ss = ((r + delta) / (alpha))**(1/(alpha-1))
Y_ss = K_ss**alpha
C_ss = Y_ss - delta * K_ss 
savings_rate_ss = K_ss / (Y_ss + (1 - delta) * K_ss)

# bounds for endogenous state variable
Kmin = K_ss * 0.5
Kmax = K_ss * 2.0
K_grid = np.linspace(Kmin, Kmax, 500)

# %% [markdown]
# ## Neural Network Definition

# %%
class DecisionNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(1, 32), # two inputs 
            nn.ReLU(),
            nn.Linear(32, 32),
            nn.ReLU(),
            nn.Linear(32, 1) # one output
        )
        # Initialize with He uniform (similar to TensorFlow's he_uniform)
        for layer in self.net:
            if isinstance(layer, nn.Linear):
                nn.init.kaiming_uniform_(layer.weight, nonlinearity='relu')
                nn.init.zeros_(layer.bias)
    
    def forward(self, x):
        return self.net(x)

network = DecisionNetwork().to(device)

# %%
def policy_function(K):
    """Decision rule: maps states to savings rate"""
    
    # Normalize inputs to roughly [-1, 1] range
    K_normalized = 2.0 * (K - Kmin) / (Kmax - Kmin) - 1.0
    
    # Stack inputs: shape (n, 1)
    s = torch.stack([K_normalized], dim=1)
    
    # Forward pass through network
    x = network(s)  # (n, 1)
    
    # Savings rate in [0,1]
    savings_rate = torch.sigmoid(x[:, 0])
        
    return torch.clamp(savings_rate, max = 0.9999)

# %%
def euler_residuals(K):
    # Current decisions
    savings_rate = policy_function(K)
    coh = coh_fun(K)
    C = c_fun(savings_rate, K)
    K_next = savings_rate * coh

    # LHS: u'(C)
    LHS = C**(-gamma)

    # Next-period policy and consumption
    savings_rate_next = policy_function(K_next)
    C_next = c_fun(savings_rate_next, K_next)

    # Future returns and marginal utility
    r_next = r_fun(K_next)
    MU_next = C_next**(-gamma)
    RHS = beta * MU_next * (1.0 + r_next)

    # Residual
    R = RHS / LHS - 1.0
    return R

# %% [markdown]
# ## Objective Function

# %%
def objective_function(n):
    K = torch.rand(n, device=device) * (Kmax - Kmin) + Kmin
    R = euler_residuals(K)
    R_squared = R**2
    return torch.mean(R_squared)

# %% [markdown]
# ## Test the Objective

# %%
n = 256
v = objective_function(n)
print(f"Initial objective value: {v.item():.6f}")
# Out:
# Initial objective value: 39.318901

# %% [markdown]
# ## Training Loop

# %%
optimizer = torch.optim.Adam(network.parameters(), lr=1e-5)

def training_step():
    optimizer.zero_grad()
    loss = objective_function(n)  
    loss.backward()
    optimizer.step()
    return loss.item()

def train(K):
    vals = []
    for k in tqdm(range(K)):
        val = training_step()
        vals.append(val)
    return vals

# %%
results = train(100_000)
# Out:
# 100%|██████████| 100000/100000 [00:41<00:00, 2401.48it/s]

# %% [markdown]
# ## Training Convergence

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.sqrt(np.abs(results)))  # abs() for numerical safety
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('RMSE of Residuals')
plt.title('Training Convergence')
plt.grid(True, which="both", ls="-", alpha=0.5)
plt.show()

# %%
euler_residuals(torch.tensor([K_ss], device=device))
# Out:
# tensor([0.0002], grad_fn=<SubBackward0>)

# %%
print(policy_function(torch.tensor([K_ss], device=device)))
print(savings_rate_ss)
# Out:
# tensor([0.6975], grad_fn=<ClampBackward1>)
# 0.6976744186046512

# %% [markdown]
# ## Compare Deep Learning vs VFI

# %%
from ramsey_vfi import vfi, extract_policies, K_grid

_, policy_K = vfi(tol = 1e-6, max_iter = 1000, verbose = True)
policy_C, policy_s = extract_policies(policy_K)
# Out:
# Iteration 1: max value function diff = 0.38179260
# Iteration 2: max value function diff = 0.10017826
# Iteration 3: max value function diff = 0.03773941
# Iteration 4: max value function diff = 0.03383830
# Iteration 5: max value function diff = 0.03030465
# Iteration 6: max value function diff = 0.02711008
# Iteration 7: max value function diff = 0.02422959
# Iteration 8: max value function diff = 0.02163973
# Iteration 9: max value function diff = 0.01931442
# Iteration 10: max value function diff = 0.01723237
# Iteration 11: max value function diff = 0.01537191
# Iteration 12: max value function diff = 0.01371158
# Iteration 13: max value function diff = 0.01223067
# Iteration 14: max value function diff = 0.01091201
# Iteration 15: max value function diff = 0.00973784
# Iteration 16: max value function diff = 0.00869297
# Iteration 17: max value function diff = 0.00776294
# Iteration 18: max value function diff = 0.00693463
# Iteration 19: max value function diff = 0.00619906
# Iteration 20: max value function diff = 0.00554209
# Iteration 21: max value function diff = 0.00495723
# Iteration 22: max value function diff = 0.00443601
# Iteration 23: max value function diff = 0.00397165
# Iteration 24: max value function diff = 0.00355729
# Iteration 25: max value function diff = 0.00318678
# Iteration 26: max value function diff = 0.00285635
# Iteration 27: max value function diff = 0.00256066
# Iteration 28: max value function diff = 0.00229659
# Iteration 29: max value function diff = 0.00206010
# Iteration 30: max value function diff = 0.00184844
# Iteration 31: max value function diff = 0.00165950
# Iteration 32: max value function diff = 0.00148960
# Iteration 33: max value function diff = 0.00133766
# Iteration 34: max value function diff = 0.00120134
# Iteration 35: max value function diff = 0.00107914
# Iteration 36: max value function diff = 0.00096959
# Iteration 37: max value function diff = 0.00087125
# Iteration 38: max value function diff = 0.00078299
# Iteration 39: max value function diff = 0.00070377
# Iteration 40: max value function diff = 0.00063264
# Iteration 41: max value function diff = 0.00056879
# Iteration 42: max value function diff = 0.00051140
# Iteration 43: max value function diff = 0.00045984
# Iteration 44: max value function diff = 0.00041351
# Iteration 45: max value function diff = 0.00037189
# Iteration 46: max value function diff = 0.00033448
# Iteration 47: max value function diff = 0.00030085
# Iteration 48: max value function diff = 0.00027061
# Iteration 49: max value function diff = 0.00024343
# Iteration 50: max value function diff = 0.00021899
# Iteration 51: max value function diff = 0.00019701
# Iteration 52: max value function diff = 0.00017724
# Iteration 53: max value function diff = 0.00015946
# Iteration 54: max value function diff = 0.00014347
# Iteration 55: max value function diff = 0.00012909
# Iteration 56: max value function diff = 0.00011615
# Iteration 57: max value function diff = 0.00010451
# Iteration 58: max value function diff = 0.00009404
# Iteration 59: max value function diff = 0.00008462
# Iteration 60: max value function diff = 0.00007614
# Iteration 61: max value function diff = 0.00006852
# Iteration 62: max value function diff = 0.00006166
# Iteration 63: max value function diff = 0.00005548
# Iteration 64: max value function diff = 0.00004993
# Iteration 65: max value function diff = 0.00004493
# Iteration 66: max value function diff = 0.00004044
# Iteration 67: max value function diff = 0.00003639
# Iteration 68: max value function diff = 0.00003275
# Iteration 69: max value function diff = 0.00002947
# Iteration 70: max value function diff = 0.00002652
# Iteration 71: max value function diff = 0.00002387
# Iteration 72: max value function diff = 0.00002148
# Iteration 73: max value function diff = 0.00001933
# Iteration 74: max value function diff = 0.00001740
# Iteration 75: max value function diff = 0.00001566
# Iteration 76: max value function diff = 0.00001409
# Iteration 77: max value function diff = 0.00001268
# Iteration 78: max value function diff = 0.00001141
# Iteration 79: max value function diff = 0.00001027
# Iteration 80: max value function diff = 0.00000924
# Iteration 81: max value function diff = 0.00000832
# Iteration 82: max value function diff = 0.00000749
# Iteration 83: max value function diff = 0.00000674
# Iteration 84: max value function diff = 0.00000606
# Iteration 85: max value function diff = 0.00000546
# Iteration 86: max value function diff = 0.00000491
# Iteration 87: max value function diff = 0.00000442
# Iteration 88: max value function diff = 0.00000398
# Iteration 89: max value function diff = 0.00000358
# Iteration 90: max value function diff = 0.00000322
# Iteration 91: max value function diff = 0.00000290
# Iteration 92: max value function diff = 0.00000261
# Iteration 93: max value function diff = 0.00000235
# Iteration 94: max value function diff = 0.00000211
# Iteration 95: max value function diff = 0.00000190
# Iteration 96: max value function diff = 0.00000171
# Iteration 97: max value function diff = 0.00000154
# Iteration 98: max value function diff = 0.00000139
# Iteration 99: max value function diff = 0.00000125
# Iteration 100: max value function diff = 0.00000112
# Iteration 101: max value function diff = 0.00000101
# Iteration 102: max value function diff = 0.00000091
#
# Converged after 102 iterations!

# %%
coh = coh_fun(K_grid)
s = policy_function(torch.tensor([K_grid], dtype = torch.float32)[0]).detach().numpy() 
K_next_dl = coh * s 

plt.plot(K_grid, policy_K , label = 'VFI')
plt.plot(K_grid, K_next_dl, label = 'DL', linestyle = ':')
plt.plot(K_grid, K_grid, color = 'black', linestyle = ':', label = '45°')
plt.axvline(x = K_ss, color = 'grey')
plt.legend()
plt.show()

# %%
# Diagnostics: check K' bounds vs VFI constraints
K_tensor = torch.tensor(K_grid, dtype=torch.float32, device=device)
s_dl = policy_function(K_tensor).detach().cpu().numpy()
coh = coh_fun(K_grid)
K_next_dl = coh * s_dl
print("K_min:", Kmin, "K_max:", Kmax)
print("K_next_dl min/max:", K_next_dl.min(), K_next_dl.max())
print("Violations below K_min:", (K_next_dl < Kmin).sum())
print("Violations above K_max:", (K_next_dl > Kmax).sum())
print("Min (coh - K_next_dl):", (coh - K_next_dl).min())
# Out:
# K_min: 1.48798955633395 K_max: 5.9519582253358
# K_next_dl min/max: 2.434081162053848 3.514664290023177
# Violations below K_min: 0
# Violations above K_max: 0
# Min (coh - K_next_dl): 1.1629458673547615
