# %%
import torch
import torch.nn as nn
import numpy as np
from math import sqrt
from matplotlib import pyplot as plt
from tqdm import tqdm

# Set device - use GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %% [markdown]
# ## Model Parameters

# %%
## Preferences
beta = 0.9 
gamma = 2.0 

## Firms
alpha = 1/3 
delta = 0.05 

## TFP 
sigma_Z = 0.001
rho_Z = 0.9
mu_Z = np.exp(1/2 * sigma_Z**2 / (1 - rho_Z**2))

# %%
def production_function(Z, K):
    """Cobb-Douglas production function"""
    return Z * K**alpha 

def coh_fun(Z, K):
    return production_function(Z, K) + (1 - delta) * K

def r_fun(Z, K):
    """Return the interest rate given Z and K"""
    return alpha * production_function(Z, K) / K - delta 

def c_fun(savings_rate, Z, K):
    """Consumption function given savings rate, TFP Z and capital K"""
    coh = coh_fun(Z, K)
    return (1 - savings_rate) * coh

# %% [markdown]
# ## Stochastic Solution Domain
#
# For AR(1) processes, the ergodic distribution has standard deviation $\sigma_z = \frac{\sigma}{\sqrt{1-\rho^2}}$

# %%
# Steady-state 
r = 1/beta - 1 
Z_ss = 1
K_ss = ((r + delta) / (alpha * Z_ss))**(1/(alpha-1))
Y_ss = K_ss**alpha
C_ss = Y_ss - delta * K_ss 
savings_rate_ss = K_ss / (Y_ss + (1 - delta) * K_ss)

# bounds for endogenous state variable
Kmin = K_ss * 0.5
Kmax = K_ss * 2.5
K_grid = np.linspace(Kmin, Kmax, 500)

# %%
print(Kmin)
print(K_ss )
print(Kmax )
# Out:
# 1.48798955633395
# 2.9759791126679
# 7.43994778166975

# %% [markdown]
# ## Neural Network Definition

# %%
class DecisionNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(2, 32), # two inputs 
            nn.ReLU(),
            nn.Linear(32, 32),
            nn.ReLU(),
            nn.Linear(32, 32),
            nn.ReLU(),
            nn.Linear(32, 1) # one output
        )
        ## Initialize with He uniform (similar to TensorFlow's he_uniform)
        #for layer in self.net:
        #    if isinstance(layer, nn.Linear):
        #        nn.init.kaiming_uniform_(layer.weight, nonlinearity='relu')
        #        nn.init.zeros_(layer.bias)
    
    def forward(self, x):
        return self.net(x)

perceptron = DecisionNetwork().to(device)
print(perceptron)
# Out:
# DecisionNetwork(
#   (net): Sequential(
#     (0): Linear(in_features=2, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=32, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
def policy_function(Z, K):
    """Decision rule: maps states to savings rate"""
    
    # Normalize inputs to roughly [-1, 1] range
    Z_normalized = (Z-mu_Z) / sigma_Z / 2
    K_normalized = 2.0 * (K - Kmin) / (Kmax - Kmin) - 1.0
    
    # Stack inputs: shape (n, 2)
    s = torch.stack([Z_normalized, K_normalized], dim=1)
    
    # Forward pass through network
    x = perceptron(s)  # (n, 1)
    
    # Savings rate in [0,1]
    savings_rate = torch.sigmoid(x[:, 0])
        
    return torch.clamp(savings_rate, min = 0.1, max = 0.9999)

# %%
def euler_residuals(Z, K, eps):
    """
    Euler residuals with Monte Carlo expectation over epsilon shocks.

    Assumes: log Z' = rho * log Z + eps,  eps ~ N(0, sigma_eps^2)
    (If you have a nonzero drift, add it below.)

    Args:
        iz: current index of TFP in the grid, shape (batch_size,)
        K: current capital, shape (batch_size,)
        n_mc: number of Monte Carlo draws per state

    Returns:
        R: Euler equation residual, shape (batch_size,)
    """
    # Current Z (levels) from grid and batch size
    n = K.shape[0]

    # Current decisions
    savings_rate = policy_function(Z, K)
    coh = coh_fun(Z, K)
    K_next = savings_rate * coh
    C = coh - K_next

    # LHS: u'(C)
    LHS = C**(-gamma)

    # Compute Z' in levels: Z' = exp(rho * log Z + eps)
    logZ = torch.log(Z)
    logZ_next = rho_Z * logZ + eps
    Z_next = torch.exp(logZ_next)

    # Next-period policy and consumption
    savings_rate_next = policy_function(Z_next, K_next)
    C_next = c_fun(savings_rate_next, Z_next, K_next)

    # Future returns and marginal utility
    r_next = r_fun(Z_next, K_next)
    MU_next = C_next**(-gamma)
    RHS = beta * MU_next * (1.0 + r_next)

    # Residual
    R = RHS / LHS - 1.0
    return R

# %% [markdown]
# ## Objective Function

# %%
def sample_Z_ergodic(n, rho, sigma_eps, *, device=None, dtype=torch.float32):
    if not (-1.0 < rho < 1.0):
        raise ValueError("Need |rho| < 1 for a stationary (ergodic) distribution.")
    device = device or torch.device("cpu")
    rho = torch.as_tensor(rho, device=device, dtype=dtype)
    sigma_eps = torch.as_tensor(sigma_eps, device=device, dtype=dtype)

    sigma_x = sigma_eps / torch.sqrt(1.0 - rho**2)          # std of log Z in stationarity
    x = sigma_x * torch.randn(n, device=device, dtype=dtype) # mean 0
    Z = torch.exp(x)
    return Z

def objective_function(n):
    """
    Objective function: minimize E[R1 * R2] where R is the Euler residual.
    
    Uses the all-in-one expectation trick with two independent shock draws.
    
    Args:
        n: Number of state samples (Z, K)
    
    Returns:
        loss: Mean product of Euler residuals
    """
    # Sample current states from ergodic distribution
    Z = sample_Z_ergodic(n, rho_Z, sigma_Z, device=device)
    K = torch.rand(n, device=device) * (Kmax - Kmin) + Kmin

    # Compute Euler residual with two independent shocks
    eps_1 = sigma_Z * torch.randn(n, device=device)
    R1 = euler_residuals(Z, K, eps_1)

    eps_2 = sigma_Z * torch.randn(n, device=device)
    R2 = euler_residuals(Z, K, eps_2)
    
    # Minimize product of residuals (all-in-one expectation)
    R_squared = R1 * R2
    return torch.mean(R_squared)

# %%
optimizer = torch.optim.Adam(perceptron.parameters(), lr=1e-4)
n = 128

def training_step():
    optimizer.zero_grad()
    loss = objective_function(n)  
    loss.backward()
    optimizer.step()
    return loss.item()

def train(K):
    vals = []
    for k in tqdm(range(K)):
        val = training_step()
        vals.append(val)
    return vals

# %%
results = train(50_000)
# Out:
# 100%|██████████| 50000/50000 [00:45<00:00, 1089.03it/s]

# %% [markdown]
# ## Training Convergence

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.sqrt(np.abs(results)))  # abs() for numerical safety
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('RMSE of Residuals')
plt.title('Training Convergence')
plt.grid(True, which="both", ls="-", alpha=0.5)
plt.show()

# %%
from rbc_vfi import vfi, extract_policies, K_grid, Z_grid as Z_grid_vfi

_, policy_K = vfi(tol = 1e-6, max_iter = 1000, verbose = True)
policy_C, policy_s = extract_policies(policy_K)
# Out:
# Iteration 1: max value function diff = 0.61171308
# Iteration 2: max value function diff = 0.36010509
# Iteration 3: max value function diff = 0.22931787
# Iteration 4: max value function diff = 0.15287448
# Iteration 5: max value function diff = 0.13248781
# Iteration 6: max value function diff = 0.11512936
# Iteration 7: max value function diff = 0.10001046
# Iteration 8: max value function diff = 0.08685792
# Iteration 9: max value function diff = 0.07544426
# Iteration 10: max value function diff = 0.06553160
# Iteration 11: max value function diff = 0.05695422
# Iteration 12: max value function diff = 0.04953408
# Iteration 13: max value function diff = 0.04310289
# Iteration 14: max value function diff = 0.03754331
# Iteration 15: max value function diff = 0.03276332
# Iteration 16: max value function diff = 0.02861080
# Iteration 17: max value function diff = 0.02500686
# Iteration 18: max value function diff = 0.02188527
# Iteration 19: max value function diff = 0.01918693
# Iteration 20: max value function diff = 0.01684540
# Iteration 21: max value function diff = 0.01480758
# Iteration 22: max value function diff = 0.01303279
# Iteration 23: max value function diff = 0.01148559
# Iteration 24: max value function diff = 0.01013475
# Iteration 25: max value function diff = 0.00895387
# Iteration 26: max value function diff = 0.00791983
# Iteration 27: max value function diff = 0.00701307
# Iteration 28: max value function diff = 0.00621677
# Iteration 29: max value function diff = 0.00551654
# Iteration 30: max value function diff = 0.00489995
# Iteration 31: max value function diff = 0.00435631
# Iteration 32: max value function diff = 0.00387636
# Iteration 33: max value function diff = 0.00345213
# Iteration 34: max value function diff = 0.00307671
# Iteration 35: max value function diff = 0.00274410
# Iteration 36: max value function diff = 0.00244911
# Iteration 37: max value function diff = 0.00218723
# Iteration 38: max value function diff = 0.00195451
# Iteration 39: max value function diff = 0.00174751
# Iteration 40: max value function diff = 0.00156325
# Iteration 41: max value function diff = 0.00139907
# Iteration 42: max value function diff = 0.00125270
# Iteration 43: max value function diff = 0.00112210
# Iteration 44: max value function diff = 0.00100550
# Iteration 45: max value function diff = 0.00090134
# Iteration 46: max value function diff = 0.00080822
# Iteration 47: max value function diff = 0.00072495
# Iteration 48: max value function diff = 0.00065044
# Iteration 49: max value function diff = 0.00058373
# Iteration 50: max value function diff = 0.00052399
# Iteration 51: max value function diff = 0.00047046
# Iteration 52: max value function diff = 0.00042249
# Iteration 53: max value function diff = 0.00037948
# Iteration 54: max value function diff = 0.00034090
# Iteration 55: max value function diff = 0.00030630
# Iteration 56: max value function diff = 0.00027524
# Iteration 57: max value function diff = 0.00024737
# Iteration 58: max value function diff = 0.00022235
# Iteration 59: max value function diff = 0.00019988
# Iteration 60: max value function diff = 0.00017969
# Iteration 61: max value function diff = 0.00016157
# Iteration 62: max value function diff = 0.00014528
# Iteration 63: max value function diff = 0.00013064
# Iteration 64: max value function diff = 0.00011749
# Iteration 65: max value function diff = 0.00010567
# Iteration 66: max value function diff = 0.00009504
# Iteration 67: max value function diff = 0.00008549
# Iteration 68: max value function diff = 0.00007690
# Iteration 69: max value function diff = 0.00006918
# Iteration 70: max value function diff = 0.00006223
# Iteration 71: max value function diff = 0.00005599
# Iteration 72: max value function diff = 0.00005037
# Iteration 73: max value function diff = 0.00004532
# Iteration 74: max value function diff = 0.00004077
# Iteration 75: max value function diff = 0.00003669
# Iteration 76: max value function diff = 0.00003301
# Iteration 77: max value function diff = 0.00002970
# Iteration 78: max value function diff = 0.00002673
# Iteration 79: max value function diff = 0.00002405
# Iteration 80: max value function diff = 0.00002164
# Iteration 81: max value function diff = 0.00001947
# Iteration 82: max value function diff = 0.00001752
# Iteration 83: max value function diff = 0.00001577
# Iteration 84: max value function diff = 0.00001419
# Iteration 85: max value function diff = 0.00001277
# Iteration 86: max value function diff = 0.00001149
# Iteration 87: max value function diff = 0.00001034
# Iteration 88: max value function diff = 0.00000931
# Iteration 89: max value function diff = 0.00000838
# Iteration 90: max value function diff = 0.00000754
# Iteration 91: max value function diff = 0.00000678
# Iteration 92: max value function diff = 0.00000610
# Iteration 93: max value function diff = 0.00000549
# Iteration 94: max value function diff = 0.00000494
# Iteration 95: max value function diff = 0.00000445
# Iteration 96: max value function diff = 0.00000400
# Iteration 97: max value function diff = 0.00000360
# Iteration 98: max value function diff = 0.00000324
# Iteration 99: max value function diff = 0.00000292
# Iteration 100: max value function diff = 0.00000263
# Iteration 101: max value function diff = 0.00000237
# Iteration 102: max value function diff = 0.00000213
# Iteration 103: max value function diff = 0.00000192
# Iteration 104: max value function diff = 0.00000172
# Iteration 105: max value function diff = 0.00000155
# Iteration 106: max value function diff = 0.00000140
# Iteration 107: max value function diff = 0.00000126
# Iteration 108: max value function diff = 0.00000113
# Iteration 109: max value function diff = 0.00000102
# Iteration 110: max value function diff = 0.00000092
#
# Converged after 110 iterations!

# %% [markdown]
# ## Compare Deep Learning vs VFI

# %%
with torch.no_grad():
    Kvec = torch.tensor(K_grid, dtype=torch.float32, device=device)
    ones = torch.ones_like(Kvec)  # Z = 1 (level value at steady state)
    savings_rate_vec = policy_function(ones, Kvec)


plt.plot(Kvec.cpu(), savings_rate_vec.cpu(), label='DL')
plt.plot(Kvec.cpu(), policy_s[4, :], linestyle='--', label='VFI')
plt.axvline(x=K_ss, linestyle='--', color='grey', alpha=0.5)
plt.axhline(y=savings_rate_ss, linestyle='--', color='grey', alpha=0.5)
plt.xlabel("$K_t$")
plt.ylabel("Savings rate")
plt.title("Savings Rate")
plt.grid()

plt.tight_layout()
plt.show()

coh = coh_fun(ones, Kvec)
K_next_dl = savings_rate_vec * coh
K_next_vfi = policy_s * coh.cpu().numpy()
plt.plot(Kvec.cpu(), Kvec.cpu(), 'k--', alpha=0.5, label='45° line')
plt.plot(Kvec.cpu(), K_next_vfi[4,:], label=f'VFI')
plt.plot(Kvec.cpu(), K_next_dl.cpu(), label=f'DL', linestyle = ':')
plt.axvline(x=K_ss, linestyle=':', color='gray', alpha=0.5)
plt.xlabel('Capital K')
plt.ylabel("K'(Z, K)")
plt.title('Capital Policy')
plt.legend()
plt.grid()
plt.show()
